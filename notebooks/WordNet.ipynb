# %%
# # wordnetのダウンロード
# import nltk
# nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\onewood\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
from nltk.corpus import wordnet as wn

import networkx as nx

from bokeh.io import output_notebook, show
from bokeh.plotting import figure, from_networkx
from bokeh.models import HoverTool, MultiLine, Circle#, Plot, NodesAndLinkedEdges, Range1d, BoxSelectTool, EdgesAndLinkedNodes, TapTool
from bokeh.palettes import Spectral4
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # WordNetで遊ぶ

# %% [markdown]
# ## ある単語が所属する同義語集合(=概念)を見る

# %%
# occupationには名詞として5つの意味があることがわかる
# 「occupation.n.01」は「occupationという単語の名詞の1番目の意味」ということ
# 「Synset('occupation.n.01')」は「occupationという単語の名詞の1番目の意味と同義の単語の集合」ということ
wn.synsets('occupation')
# Out:
# [Synset('occupation.n.01'),
#  Synset('occupation.n.02'),
#  Synset('occupation.n.03'),
#  Synset('occupation.n.04'),
#  Synset('occupation.n.05')]

# %%
# designには名詞,動詞それぞれ7つの意味があることがわかる
wn.synsets('design')
# Out:
# [Synset('design.n.01'),
#  Synset('design.n.02'),
#  Synset('blueprint.n.01'),
#  Synset('design.n.04'),
#  Synset('purpose.n.01'),
#  Synset('design.n.06'),
#  Synset('invention.n.01'),
#  Synset('plan.v.03'),
#  Synset('design.v.02'),
#  Synset('design.v.03'),
#  Synset('design.v.04'),
#  Synset('design.v.05'),
#  Synset('design.v.06'),
#  Synset('design.v.07')]

# %%
# 品詞を指定する
print(wn.synsets('design', pos=wn.NOUN))
print(wn.synsets('design', pos='n'))
# Out:
# [Synset('design.n.01'), Synset('design.n.02'), Synset('blueprint.n.01'), Synset('design.n.04'), Synset('purpose.n.01'), Synset('design.n.06'), Synset('invention.n.01')]
# [Synset('design.n.01'), Synset('design.n.02'), Synset('blueprint.n.01'), Synset('design.n.04'), Synset('purpose.n.01'), Synset('design.n.06'), Synset('invention.n.01')]

# %% [markdown]
# ## 同義語集合に属する単語を見る

# %%
wn.synset('occupation.n.01').lemma_names()
# Out:
# ['occupation', 'business', 'job', 'line_of_work', 'line']

# %% [markdown]
# ## 同義語集合の定義を見る

# %%
wn.synset('occupation.n.01').definition()
# Out:
# 'the principal activity in your life that you do to earn money'

# %% [markdown]
# ## 同義語集合の例文を見る

# %%
wn.synset('occupation.n.01').examples()
# Out:
# ["he's not in my line of business"]

# %% [markdown]
# ## 同義語集合の名前を見る

# %%
print(wn.synsets('occupation')[0].name())
# 得た名前を使って同義語集合を出す
print(wn.synset(wn.synsets('occupation')[0].name()) == wn.synsets('occupation')[0])
# Out:
# occupation.n.01
# True

# %% [markdown]
# ## 上位概念を見る

# %%
wn.synset('occupation.n.01').hypernyms()
# Out:
# [Synset('activity.n.01')]

# %% [markdown]
# ## 下位概念を見る

# %%
wn.synset('occupation.n.01').hyponyms()
# Out:
# [Synset('accountancy.n.01'),
#  Synset('appointment.n.05'),
#  Synset('career.n.01'),
#  Synset('catering.n.01'),
#  Synset('confectionery.n.03'),
#  Synset('employment.n.02'),
#  Synset('farming.n.02'),
#  Synset('game.n.10'),
#  Synset('metier.n.02'),
#  Synset('photography.n.03'),
#  Synset('position.n.06'),
#  Synset('profession.n.02'),
#  Synset('sport.n.02'),
#  Synset('trade.n.02'),
#  Synset('treadmill.n.03')]

# %% [markdown]
# ## ある概念の構成要素を求める

# %%
wn.synset('water.n.01').substance_meronyms()
# Out:
# [Synset('hydrogen.n.01'), Synset('oxygen.n.01')]

# %% [markdown]
# ## ある概念の部品を求める

# %%
wn.synset('car.n.01').part_meronyms()
# Out:
# [Synset('accelerator.n.01'),
#  Synset('air_bag.n.01'),
#  Synset('auto_accessory.n.01'),
#  Synset('automobile_engine.n.01'),
#  Synset('automobile_horn.n.01'),
#  Synset('buffer.n.06'),
#  Synset('bumper.n.02'),
#  Synset('car_door.n.01'),
#  Synset('car_mirror.n.01'),
#  Synset('car_seat.n.01'),
#  Synset('car_window.n.01'),
#  Synset('fender.n.01'),
#  Synset('first_gear.n.01'),
#  Synset('floorboard.n.02'),
#  Synset('gasoline_engine.n.01'),
#  Synset('glove_compartment.n.01'),
#  Synset('grille.n.02'),
#  Synset('high_gear.n.01'),
#  Synset('hood.n.09'),
#  Synset('luggage_compartment.n.01'),
#  Synset('rear_window.n.01'),
#  Synset('reverse.n.02'),
#  Synset('roof.n.02'),
#  Synset('running_board.n.01'),
#  Synset('stabilizer_bar.n.01'),
#  Synset('sunroof.n.01'),
#  Synset('tail_fin.n.02'),
#  Synset('third_gear.n.01'),
#  Synset('window.n.02')]

# %% [markdown]
# ## ある単語の対義語を求める

# %%
# wn.synset('push.n.01').lemma_names()[0].antonyms()
wn.lemma('push.v.01.push').antonyms()
# Out:
# [Lemma('pull.v.01.pull')]

# %% [markdown]
# # 職業の集合を探す

# %%
def show_graph(graph):
    p = figure(x_range=(-1.1,1.1), y_range=(-1.1,1.1))
    
    g = from_networkx(graph, nx.multipartite_layout, center=(0,0))

    g.node_renderer.glyph = Circle(size=25, fill_color=Spectral4[0])
    g.edge_renderer.glyph = MultiLine(line_color="#CCCCCC", line_alpha=0.8, line_width=5)
    
    node_hover_tool = HoverTool(tooltips=[("index", "@index")])
    p.add_tools(node_hover_tool)
    
    p.renderers.append(g)
    show(p)

# %%
def add_synset(graph, new, hyper_list=None, hypo_list=None, first=False):
    graph.add_node(new.name())
    if not first:
        for hyper in hyper_list:
            for hypo in hypo_list:
                graph.add_edge(hyper.name(), hypo.name())
    if first:
        graph.nodes[new.name()]['subset'] = 0
    elif new in hyper_list:
        graph.nodes[new.name()]['subset'] = graph.nodes[hypo_list[0].name()]['subset'] - 1
    elif new in hypo_list:
        graph.nodes[new.name()]['subset'] = graph.nodes[hyper_list[0].name()]['subset'] + 1

# %%
def print_synset(synsets, first=0):
    for i, syn in enumerate(synsets):
        print(i+first)
        print('words:', syn.lemma_names())
        print('def:', syn.definition())
        print('\n')

# %% [markdown]
# ## occupationから探す

# %%
G = nx.DiGraph()

# %%
wn.synsets('occupation')
# Out:
# [Synset('occupation.n.01'),
#  Synset('occupation.n.02'),
#  Synset('occupation.n.03'),
#  Synset('occupation.n.04'),
#  Synset('occupation.n.05')]

# %%
print_synset(wn.synsets('occupation'))
# Out:
# 0
# words: ['occupation', 'business', 'job', 'line_of_work', 'line']
# def: the principal activity in your life that you do to earn money
#
#
# 1
# words: ['occupation', 'military_control']
# def: the control of a country by military forces of a foreign power
#
#
# 2
# words: ['occupation']
# def: any activity that occupies a person's attention
#
#
# 3
# words: ['occupation', 'occupancy', 'moving_in']
# def: the act of occupying or taking possession of a building
#
#
# 4
# words: ['occupation']
# def: the period of time during which a place or position or nation is occupied

# %%
occupation = wn.synsets('occupation')[0]
add_synset(G, occupation, first=True)

# %%
print_synset(occupation.hyponyms())
# Out:
# 0
# words: ['accountancy', 'accounting']
# def: the occupation of maintaining and auditing records and preparing financial reports for a business
#
#
# 1
# words: ['appointment']
# def: the job to which you are (or hope to be) appointed
#
#
# 2
# words: ['career', 'calling', 'vocation']
# def: the particular occupation for which you are trained
#
#
# 3
# words: ['catering']
# def: providing food and services
#
#
# 4
# words: ['confectionery']
# def: the occupation and skills of a confectioner
#
#
# 5
# words: ['employment', 'work']
# def: the occupation for which you are paid
#
#
# 6
# words: ['farming', 'land']
# def: agriculture considered as an occupation or way of life
#
#
# 7
# words: ['game', 'biz']
# def: your occupation or line of work
#
#
# 8
# words: ['metier', 'medium']
# def: an occupation for which you are especially well suited
#
#
# 9
# words: ['photography']
# def: the occupation of taking and printing photographs or making movies
#
#
# 10
# words: ['position', 'post', 'berth', 'office', 'spot', 'billet', 'place', 'situation']
# def: a job in an organization
#
#
# 11
# words: ['profession']
# def: an occupation requiring special education (especially in the liberal arts or sciences)
#
#
# 12
# words: ['sport']
# def: the occupation of athletes who compete for pay
#
#
# 13
# words: ['trade', 'craft']
# def: the skilled practice of a practical occupation
#
#
# 14
# words: ['treadmill', 'salt_mine']
# def: a job involving drudgery and confinement

# %%
add_synset(G, occupation.hyponyms()[12], hyper_list=[occupation], hypo_list=[occupation.hyponyms()[12]])

# %%
show_graph(G)
# Out:
#   <div class="bk-root" id="66530bc3-3fe6-4032-863e-bcd9bbbbfeb3" data-root-id="1002"></div>

# %%
print_synset(occupation.hyponyms()[12].hyponyms())
# Out:
# 0
# words: ['professional_baseball']
# def: playing baseball for money
#
#
# 1
# words: ['professional_basketball']
# def: playing basketball for money
#
#
# 2
# words: ['professional_boxing']
# def: boxing for money
#
#
# 3
# words: ['professional_football']
# def: football played for pay
#
#
# 4
# words: ['professional_golf']
# def: playing golf for money
#
#
# 5
# words: ['professional_tennis']
# def: playing tennis for money
#
#
# 6
# words: ['professional_wrestling']
# def: wrestling for money
#
#
# 7
# words: ['sumo']
# def: a Japanese form of wrestling; you lose if you are forced out of a small ring or if any part of your body (other than your feet) touches the ground

# %% [markdown]
# ## 職業単語から探す

# %%
wn.synsets('football_player')
# Out:
# [Synset('football_player.n.01')]

# %%
print_synset(wn.synsets('football_player'))
# Out:
# 0
# words: ['football_player', 'footballer']
# def: an athlete who plays American football

# %%
footballer = wn.synsets('football_player')[0]
G = nx.DiGraph()
add_synset(G, footballer, first=True)

# %%
footballer.hypernyms()
# Out:
# [Synset('athlete.n.01'), Synset('player.n.01')]

# %%
print_synset(footballer.hypernyms())
# Out:
# 0
# words: ['athlete', 'jock']
# def: a person trained to compete in sports
#
#
# 1
# words: ['player', 'participant']
# def: a person who participates in or is skilled at some game

# %%
for syn in footballer.hypernyms():
    add_synset(G, syn, hyper_list=[syn], hypo_list=[footballer])

# %%
show_graph(G)
# Out:
#   <div class="bk-root" id="a31dcffa-c91a-4f4d-ad26-60fb2f1f3c68" data-root-id="1193"></div>

# %%
for syn in footballer.hypernyms():
    print_synset(syn.hypernyms())
# Out:
# 0
# words: ['contestant']
# def: a person who participates in competitions
#
#
# 0
# words: ['contestant']
# def: a person who participates in competitions

# %%
add_synset(G, footballer.hypernyms()[0].hypernyms()[0],
           hyper_list=[footballer.hypernyms()[0].hypernyms()[0]], hypo_list=footballer.hypernyms())

# %%
show_graph(G)
# Out:
#   <div class="bk-root" id="a17046b7-09c6-4252-b20b-f5c057f482a4" data-root-id="1405"></div>

# %%
wn.synset('contestant.n.01').hypernyms()
# Out:
# [Synset('person.n.01')]

# %%
print_synset(wn.synset('contestant.n.01').hypernyms())
# Out:
# 0
# words: ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul']
# def: a human being

# %%
add_synset(G, wn.synset('person.n.01'),
           hyper_list=[wn.synset('person.n.01')], hypo_list=[wn.synset('contestant.n.01')])

# %%
show_graph(G)
# Out:
#   <div class="bk-root" id="4f4f9d5e-b9f8-41b7-b793-3a3edad4c2a1" data-root-id="1638"></div>

# %%
print_synset(wn.synsets('doctor'))
# Out:
# 0
# words: ['doctor', 'doc', 'physician', 'MD', 'Dr.', 'medico']
# def: a licensed medical practitioner
#
#
# 1
# words: ['Doctor_of_the_Church', 'Doctor']
# def: (Roman Catholic Church) a title conferred on 33 saints who distinguished themselves through the orthodoxy of their theological teaching
#
#
# 2
# words: ['doctor']
# def: children take the roles of physician or patient or nurse and pretend they are at the physician's office
#
#
# 3
# words: ['doctor', 'Dr.']
# def: a person who holds Ph.D. degree (or the equivalent) from an academic institution
#
#
# 4
# words: ['sophisticate', 'doctor', 'doctor_up']
# def: alter and make impure, as with the intention to deceive
#
#
# 5
# words: ['doctor']
# def: give medical treatment to
#
#
# 6
# words: ['repair', 'mend', 'fix', 'bushel', 'doctor', 'furbish_up', 'restore', 'touch_on']
# def: restore by replacing a part or putting together what is torn or broken

# %%
doctor = wn.synsets('doctor')[0]

# %%
add_synset(G, wn.synset('adult.n.01'),
           hyper_list=[wn.synset('person.n.01')], hypo_list=[wn.synset('adult.n.01')])

# %%
show_graph(G)
# Out:
#   <div class="bk-root" id="9b50e5ff-31cc-448f-ba9c-48542a336108" data-root-id="1892"></div>

# %%
add_synset(G, wn.synset('professional.n.01'),
           hyper_list=[wn.synset('adult.n.01')], hypo_list=[wn.synset('professional.n.01')])
show_graph(G)
# Out:
#   <div class="bk-root" id="8f84239a-9020-4088-949d-104ff9ea01b2" data-root-id="2167"></div>

# %%
add_synset(G, wn.synset('health_professional.n.01'),
           hyper_list=[wn.synset('professional.n.01')], hypo_list=[wn.synset('health_professional.n.01')])
show_graph(G)
# Out:
#   <div class="bk-root" id="334ca3d4-44fd-4af1-971b-63731b049c40" data-root-id="2463"></div>

# %%
add_synset(G, wn.synset('medical_practitioner.n.01'),
           hyper_list=[wn.synset('health_professional.n.01')], hypo_list=[wn.synset('medical_practitioner.n.01')])
show_graph(G)
# Out:
#   <div class="bk-root" id="3a4f673d-ed64-4bb9-925b-c68c9ee444d8" data-root-id="2780"></div>

# %%
add_synset(G, doctor,
           hyper_list=[wn.synset('medical_practitioner.n.01')], hypo_list=[doctor])
show_graph(G)
# Out:
#   <div class="bk-root" id="026fdbbc-487a-4129-bfb5-9215a6e58cd7" data-root-id="3118"></div>

# %%
nurse = wn.synsets('nurse')[0]

# %%
nurse.hypernyms()
# Out:
# [Synset('health_professional.n.01')]

# %%
add_synset(G, nurse,
           hyper_list=[wn.synset('health_professional.n.01')], hypo_list=[nurse])
show_graph(G)
# Out:
#   <div class="bk-root" id="e05b8d03-aa41-411c-9d6a-e5309a5390e2" data-root-id="3477"></div>

# %%
print_synset(wn.synsets('teacher'))
# Out:
# 0
# words: ['teacher', 'instructor']
# def: a person whose occupation is teaching
#
#
# 1
# words: ['teacher']
# def: a personified abstraction that teaches

# %%
teacher = wn.synsets('teacher')[0]
teacher.hypernyms()[0]
# Out:
# Synset('educator.n.01')

# %%
add_synset(G, wn.synset('educator.n.01'),
           hyper_list=[wn.synset('professional.n.01')], hypo_list=[wn.synset('educator.n.01')])
show_graph(G)
# Out:
#   <div class="bk-root" id="bbb132fd-2a9e-400a-8c35-cb3f6c48eaf2" data-root-id="3857"></div>

# %%
add_synset(G, teacher,
           hyper_list=[wn.synset('educator.n.01')], hypo_list=[teacher])
show_graph(G)
# Out:
#   <div class="bk-root" id="16541da5-5354-4fb9-bb2a-57a3c4521f17" data-root-id="4258"></div>

# %%
print_synset(wn.synsets('politician'))
# Out:
# 0
# words: ['politician']
# def: a leader engaged in civil administration
#
#
# 1
# words: ['politician', 'politico', 'pol', 'political_leader']
# def: a person active in party politics
#
#
# 2
# words: ['politician']
# def: a schemer who tries to gain advantage in an organization in sly or underhanded ways

# %%
politician = wn.synsets('politician')[1]
politician.hypernyms()[0]
# Out:
# Synset('leader.n.01')

# %%
add_synset(G, wn.synset('leader.n.01'),
           hyper_list=[wn.synset('person.n.01')], hypo_list=[wn.synset('leader.n.01')])
add_synset(G, politician,
           hyper_list=[wn.synset('leader.n.01')], hypo_list=[politician])
show_graph(G)
# Out:
#   <div class="bk-root" id="2ca30c6d-b9d7-4d9b-a8a7-8530773f4d91" data-root-id="4680"></div>

# %%
print_synset(wn.synsets('waiter'))
# Out:
# 0
# words: ['waiter', 'server']
# def: a person whose occupation is to serve at table (as in a restaurant)
#
#
# 1
# words: ['waiter']
# def: a person who waits or awaits

# %%
waiter = wn.synsets('waiter')[0]
waiter.hypernyms()[0]
# Out:
# Synset('dining-room_attendant.n.01')

# %%
add_synset(G, wn.synset('worker.n.01'),
           hyper_list=[wn.synset('person.n.01')], hypo_list=[wn.synset('worker.n.01')])
add_synset(G, wn.synset('employee.n.01'),
           hyper_list=[wn.synset('worker.n.01')], hypo_list=[wn.synset('employee.n.01')])
add_synset(G, wn.synset('dining-room_attendant.n.01'),
           hyper_list=[wn.synset('employee.n.01')], hypo_list=[wn.synset('dining-room_attendant.n.01')])
add_synset(G, waiter,
           hyper_list=[wn.synset('dining-room_attendant.n.01')], hypo_list=[waiter])
show_graph(G)
# Out:
#   <div class="bk-root" id="95f263e6-ec47-499e-b06c-dd8f88f4c455" data-root-id="5123"></div>

# %%
text = ''
for i, syn in enumerate(wn.synset('person.n.01').hyponyms()):
    text += str(i) + ': ' + syn.definition() + '\n'
with open('data/person_hyponyms.txt', mode='w') as f:
    f.write(text)

# %%
print_synset(wn.synset('person.n.01').hyponyms()[50:], first=50)
# [0,4,7,8,9,10,12,16,17,20,27,28,29,31,36,48]
# 50から
# Out:
# 50
# words: ['biter']
# def: someone who bites
#
#
# 51
# words: ['Black', 'Black_person', 'blackamoor', 'Negro', 'Negroid']
# def: a person with dark skin who comes from Africa (or whose ancestors came from Africa)
#
#
# 52
# words: ['blogger']
# def: a person who keeps and updates a blog
#
#
# 53
# words: ['blond', 'blonde']
# def: a person with fair skin and hair
#
#
# 54
# words: ['bluecoat']
# def: a person dressed all in blue (as a soldier or sailor)
#
#
# 55
# words: ['bodybuilder', 'muscle_builder', 'muscle-builder', 'musclebuilder', 'muscleman']
# def: someone who does special exercises to develop a brawny musculature
#
#
# 56
# words: ['bomber']
# def: a person who plants bombs
#
#
# 57
# words: ['brunet', 'brunette']
# def: a person with dark (brown) hair
#
#
# 58
# words: ['bullfighter', 'toreador']
# def: someone who fights bulls
#
#
# 59
# words: ['buster']
# def: a person (or thing) that breaks up or overpowers something
#
#
# 60
# words: ['Cancer', 'Crab']
# def: (astrology) a person who is born while the sun is in Cancer
#
#
# 61
# words: ['candidate', 'prospect']
# def: someone who is considered for something (for an office or prize or honor etc.)
#
#
# 62
# words: ['capitalist']
# def: a person who invests capital in a business (especially a large business)
#
#
# 63
# words: ['Capricorn', 'Goat']
# def: (astrology) a person who is born while the sun is in Capricorn
#
#
# 64
# words: ['captor', 'capturer']
# def: a person who captures and holds people or animals
#
#
# 65
# words: ['case']
# def: a person requiring professional services
#
#
# 66
# words: ['cashier']
# def: a person responsible for receiving payments for goods and services (as in a shop or restaurant)
#
#
# 67
# words: ['celebrant', 'celebrator', 'celebrater']
# def: a person who is celebrating
#
#
# 68
# words: ['censor']
# def: someone who censures or condemns
#
#
# 69
# words: ['chameleon']
# def: a changeable or inconstant person
#
#
# 70
# words: ['changer', 'modifier']
# def: a person who changes something
#
#
# 71
# words: ['charmer', 'beguiler']
# def: a person who charms others (usually by personal attractiveness)
#
#
# 72
# words: ['child', 'baby']
# def: an immature childish person
#
#
# 73
# words: ['chutzpanik']
# def: (Yiddish) a person characterized by chutzpa
#
#
# 74
# words: ['closer']
# def: a person who closes something
#
#
# 75
# words: ['clumsy_person']
# def: a person with poor motor coordination
#
#
# 76
# words: ['collector', 'aggregator']
# def: a person who collects things
#
#
# 77
# words: ['color-blind_person']
# def: a person unable to distinguish differences in hue
#
#
# 78
# words: ['combatant', 'battler', 'belligerent', 'fighter', 'scrapper']
# def: someone who fights (or is fighting)
#
#
# 79
# words: ['commoner', 'common_man', 'common_person']
# def: a person who holds no title
#
#
# 80
# words: ['communicator']
# def: a person who communicates with others
#
#
# 81
# words: ['complexifier']
# def: someone makes things complex
#
#
# 82
# words: ['compulsive']
# def: a person with a compulsive disposition; someone who feels compelled to do certain things
#
#
# 83
# words: ['computer_user']
# def: a person who uses computers for work or entertainment or communication or business
#
#
# 84
# words: ['contemplative']
# def: a person devoted to the contemplative life
#
#
# 85
# words: ['contestant']
# def: a person who participates in competitions
#
#
# 86
# words: ['convert']
# def: a person who has been converted to another religious or political belief
#
#
# 87
# words: ['copycat', 'imitator', 'emulator', 'ape', 'aper']
# def: someone who copies the words or behavior of another
#
#
# 88
# words: ['counter']
# def: a person who counts things
#
#
# 89
# words: ['counterterrorist']
# def: someone who attempts to prevent terrorism
#
#
# 90
# words: ['coward']
# def: a person who shows fear or timidity
#
#
# 91
# words: ['crawler', 'creeper']
# def: a person who crawls or creeps along the ground
#
#
# 92
# words: ['creator']
# def: a person who grows or makes or invents things
#
#
# 93
# words: ['creature', 'wight']
# def: a human being; `wight' is an archaic term
#
#
# 94
# words: ['creditor']
# def: a person to whom money is owed by a debtor; someone to whom an obligation exists
#
#
# 95
# words: ['cripple']
# def: someone who is unable to walk normally because of an injury or disability to the legs or back
#
#
# 96
# words: ['dancer', 'social_dancer']
# def: a person who participates in a social gathering arranged for dancing (as a ball)
#
#
# 97
# words: ['dead_person', 'dead_soul', 'deceased_person', 'deceased', 'decedent', 'departed']
# def: someone who is no longer alive
#
#
# 98
# words: ['deaf_person']
# def: a person with a severe auditory impairment
#
#
# 99
# words: ['debaser', 'degrader']
# def: a person who lowers the quality or character or value (as by adding cheaper metal to coins)
#
#
# 100
# words: ['debtor', 'debitor']
# def: a person who owes a creditor; someone who has the obligation of paying a debt
#
#
# 101
# words: ['defecator', 'voider', 'shitter']
# def: a person who defecates
#
#
# 102
# words: ['delayer']
# def: a person who delays; to put off until later or cause to be late
#
#
# 103
# words: ['deliverer']
# def: a person who gives up or transfers money or goods
#
#
# 104
# words: ['demander']
# def: a person who makes demands
#
#
# 105
# words: ['dieter']
# def: a person who diets
#
#
# 106
# words: ['differentiator', 'discriminator']
# def: a person who (or that which) differentiates
#
#
# 107
# words: ['disentangler', 'unraveler', 'unraveller']
# def: a person who removes tangles; someone who takes something out of a tangled state
#
#
# 108
# words: ['disputant', 'controversialist', 'eristic']
# def: a person who disputes; who is good at or enjoys controversy
#
#
# 109
# words: ['dissenter', 'dissident', 'protester', 'objector', 'contestant']
# def: a person who dissents from some established policy
#
#
# 110
# words: ['divider']
# def: a person who separates something into parts or groups
#
#
# 111
# words: ['domestic_partner', 'significant_other', 'spousal_equivalent', 'spouse_equivalent']
# def: a person (not necessarily a spouse) with whom you cohabit and share a long-term sexual relationship
#
#
# 112
# words: ['double', 'image', 'look-alike']
# def: someone who closely resembles a famous person (especially an actor)
#
#
# 113
# words: ['dresser']
# def: a person who dresses in a particular way
#
#
# 114
# words: ['dribbler', 'driveller', 'slobberer', 'drooler']
# def: a person who dribbles
#
#
# 115
# words: ['drug_user', 'substance_abuser', 'user']
# def: a person who takes drugs
#
#
# 116
# words: ['dyslectic']
# def: a person who has dyslexia
#
#
# 117
# words: ['ectomorph']
# def: a person with a thin body
#
#
# 118
# words: ['effecter', 'effector']
# def: one who brings about a result or event; one who accomplishes a purpose
#
#
# 119
# words: ['Elizabethan']
# def: a person who lived during the reign of Elizabeth I
#
#
# 120
# words: ['emotional_person']
# def: a person subject to strong states of emotion
#
#
# 121
# words: ['endomorph']
# def: a heavy person with a soft and rounded body
#
#
# 122
# words: ['engineer', 'applied_scientist', 'technologist']
# def: a person who uses scientific knowledge to solve practical problems
#
#
# 123
# words: ['enjoyer']
# def: a person who delights in having or using or experiencing something
#
#
# 124
# words: ['enrollee']
# def: a person who enrolls in (or is enrolled in) a class or course of study
#
#
# 125
# words: ['entertainer']
# def: a person who tries to please or amuse
#
#
# 126
# words: ['ethnic']
# def: a person who is a member of an ethnic group
#
#
# 127
# words: ['experimenter']
# def: a person who enjoys testing innovative ideas
#
#
# 128
# words: ['expert']
# def: a person with special knowledge or ability who performs skillfully
#
#
# 129
# words: ['explorer', 'adventurer']
# def: someone who travels into little known regions (especially for some scientific purpose)
#
#
# 130
# words: ['extrovert', 'extravert']
# def: (psychology) a person concerned more with practical realities than with inner thoughts and feelings
#
#
# 131
# words: ['face']
# def: a part of a person that is used to refer to a person
#
#
# 132
# words: ['faddist']
# def: a person who subscribes to a variety of fads
#
#
# 133
# words: ['faller']
# def: a person who falls
#
#
# 134
# words: ['fastener']
# def: a person who fastens or makes fast
#
#
# 135
# words: ['female', 'female_person']
# def: a person who belongs to the sex that can have babies
#
#
# 136
# words: ['fiduciary']
# def: a person who holds assets in trust for a beneficiary
#
#
# 137
# words: ['first-rater']
# def: one who is first-rate
#
#
# 138
# words: ['follower']
# def: a person who accepts the leadership of another
#
#
# 139
# words: ['free_agent', 'free_spirit', 'freewheeler']
# def: someone acting freely or even irresponsibly
#
#
# 140
# words: ['friend']
# def: a person you know well and regard with affection and trust
#
#
# 141
# words: ['fugitive', 'runaway', 'fleer']
# def: someone who flees from an uncongenial situation
#
#
# 142
# words: ['gainer', 'weight_gainer']
# def: a person who gains weight
#
#
# 143
# words: ['gainer']
# def: a person who gains (gains an advantage or gains profits)
#
#
# 144
# words: ['gambler']
# def: a person who wagers money on the outcome of games or sporting events
#
#
# 145
# words: ['gatekeeper']
# def: someone who controls access to something
#
#
# 146
# words: ['gatherer']
# def: a person who gathers
#
#
# 147
# words: ['Gemini', 'Twin']
# def: (astrology) a person who is born while the sun is in Gemini
#
#
# 148
# words: ['gentile']
# def: a person who is not a member of one's own religion; used in this sense by Mormons and Hindus
#
#
# 149
# words: ['good_guy']
# def: any person who is on your side
#
#
# 150
# words: ['good_person']
# def: a person who is good to other people
#
#
# 151
# words: ['granter']
# def: a person who grants or gives something
#
#
# 152
# words: ['greeter', 'saluter', 'welcomer']
# def: a person who greets
#
#
# 153
# words: ['grinner']
# def: a person who grins
#
#
# 154
# words: ['groaner']
# def: a person who groans
#
#
# 155
# words: ['grunter']
# def: a person who grunts
#
#
# 156
# words: ['guesser']
# def: a person who guesses
#
#
# 157
# words: ['handicapped_person']
# def: a person who has some condition that markedly restricts their ability to function physically or mentally or socially
#
#
# 158
# words: ['hater']
# def: a person who hates
#
#
# 159
# words: ['heterosexual', 'heterosexual_person', 'straight_person', 'straight']
# def: a heterosexual person; someone having a sexual orientation to persons of the opposite sex
#
#
# 160
# words: ['homosexual', 'homophile', 'homo', 'gay']
# def: someone who practices homosexuality; having a sexual attraction to persons of the same sex
#
#
# 161
# words: ['homunculus']
# def: a tiny fully formed individual that (according to the discredited theory of preformation) is supposed to be present in the sperm cell
#
#
# 162
# words: ['hope']
# def: someone (or something) on which expectations are centered
#
#
# 163
# words: ['hoper']
# def: a person who hopes
#
#
# 164
# words: ['huddler']
# def: a person who crouches
#
#
# 165
# words: ['hugger']
# def: a person who hugs
#
#
# 166
# words: ['immune']
# def: a person who is immune to a particular infection
#
#
# 167
# words: ['individualist']
# def: a person who pursues independent thought or action
#
#
# 168
# words: ['inhabitant', 'habitant', 'dweller', 'denizen', 'indweller']
# def: a person who inhabits a particular place
#
#
# 169
# words: ['innocent', 'inexperienced_person']
# def: a person who lacks knowledge of evil
#
#
# 170
# words: ['insured', 'insured_person']
# def: a person whose interests are protected by an insurance policy; a person who contracts for an insurance policy that indemnifies him against loss of property or life or health etc.
#
#
# 171
# words: ['intellectual', 'intellect']
# def: a person who uses the mind creatively
#
#
# 172
# words: ['interpreter']
# def: someone who uses art to represent something
#
#
# 173
# words: ['introvert']
# def: (psychology) a person who tends to shrink from social contacts and to become preoccupied with their own thoughts
#
#
# 174
# words: ['Jat']
# def: a member of an Indo-European people widely scattered throughout the northwest of the Indian subcontinent and consisting of Muslims and Hindus and Sikhs
#
#
# 175
# words: ['Jew', 'Hebrew', 'Israelite']
# def: a person belonging to the worldwide group claiming descent from Jacob (or converted to it) and connected by cultural or religious ties
#
#
# 176
# words: ['jewel', 'gem']
# def: a person who is as brilliant and precious as a piece of jewelry
#
#
# 177
# words: ['jumper']
# def: a person who jumps
#
#
# 178
# words: ['junior']
# def: the younger of two persons
#
#
# 179
# words: ['juvenile', 'juvenile_person']
# def: a young person, not fully developed
#
#
# 180
# words: ['killer', 'slayer']
# def: someone who causes the death of a person or animal
#
#
# 181
# words: ['kink']
# def: a person with unusual sexual tastes
#
#
# 182
# words: ['kneeler']
# def: a person in a kneeling position
#
#
# 183
# words: ['knocker']
# def: a person who knocks (as seeking to gain admittance)
#
#
# 184
# words: ['knower', 'apprehender']
# def: a person who knows or apprehends
#
#
# 185
# words: ['large_person']
# def: a person of greater than average size
#
#
# 186
# words: ['Latin']
# def: a person who is a member of those peoples whose languages derived from Latin
#
#
# 187
# words: ['laugher']
# def: a person who is laughing or who laughs easily
#
#
# 188
# words: ['leader']
# def: a person who rules or guides or inspires others
#
#
# 189
# words: ['learner', 'scholar', 'assimilator']
# def: someone (especially a child) who learns (as from a teacher) or takes up knowledge or beliefs
#
#
# 190
# words: ['left-hander', 'lefty', 'southpaw']
# def: a person who uses the left hand with greater skill than the right
#
#
# 191
# words: ['Leo', 'Lion']
# def: (astrology) a person who is born while the sun is in Leo
#
#
# 192
# words: ['Libra', 'Balance']
# def: (astrology) a person who is born while the sun is in Libra
#
#
# 193
# words: ['life']
# def: a living person
#
#
# 194
# words: ['lightning_rod']
# def: someone who is a frequent target of negative reactions and serves to distract attention from another
#
#
# 195
# words: ['linguist', 'polyglot']
# def: a person who speaks more than one language
#
#
# 196
# words: ['literate', 'literate_person']
# def: a person who can read and write
#
#
# 197
# words: ['liver']
# def: a person who has a special life style
#
#
# 198
# words: ['longer', 'thirster', 'yearner']
# def: a person with a strong desire for something
#
#
# 199
# words: ['loose_cannon']
# def: a person who is expected to perform a particular task but who is out of control and dangerous
#
#
# 200
# words: ['loved_one']
# def: a person who you love, usually a member of your family
#
#
# 201
# words: ['lover']
# def: a person who loves someone or is loved by someone
#
#
# 202
# words: ['machine']
# def: an efficient person
#
#
# 203
# words: ['mailer']
# def: a person who mails something
#
#
# 204
# words: ['malcontent']
# def: a person who is discontented or disgusted
#
#
# 205
# words: ['male', 'male_person']
# def: a person who belongs to the sex that cannot have babies
#
#
# 206
# words: ['man']
# def: the generic use of the word to refer to any human being
#
#
# 207
# words: ['man_jack']
# def: a single individual
#
#
# 208
# words: ['manipulator']
# def: a person who handles things manually
#
#
# 209
# words: ['married']
# def: a person who is married
#
#
# 210
# words: ['masturbator', 'onanist']
# def: a person who practices masturbation
#
#
# 211
# words: ['measurer']
# def: a person who makes measurements
#
#
# 212
# words: ['mesomorph']
# def: a person with a well-developed muscular body
#
#
# 213
# words: ['mestizo', 'ladino']
# def: a person of mixed racial ancestry (especially mixed European and Native American ancestry)
#
#
# 214
# words: ['middlebrow']
# def: someone who is neither a highbrow nor a lowbrow
#
#
# 215
# words: ['miracle_man', 'miracle_worker']
# def: a person who claims or is alleged to perform miracles
#
#
# 216
# words: ['misogamist']
# def: a person who hates marriage
#
#
# 217
# words: ['mixed-blood']
# def: a person whose ancestors belonged to two or more races
#
#
# 218
# words: ['modern']
# def: a contemporary person
#
#
# 219
# words: ['money_handler', 'money_dealer']
# def: a person who receives or invests or pays out money
#
#
# 220
# words: ['monolingual']
# def: a person who knows only one language
#
#
# 221
# words: ['mother_hen']
# def: a person who cares for the needs of others (especially in an overprotective or interfering way)
#
#
# 222
# words: ['mouse']
# def: person who is quiet or timid
#
#
# 223
# words: ['mutilator', 'maimer', 'mangler']
# def: a person who mutilates or destroys or disfigures or cripples
#
#
# 224
# words: ['namer']
# def: a person who gives a name or names
#
#
# 225
# words: ['namesake']
# def: a person with the same name as another
#
#
# 226
# words: ['national', 'subject']
# def: a person who owes allegiance to that nation
#
#
# 227
# words: ['native', 'indigen', 'indigene', 'aborigine', 'aboriginal']
# def: an indigenous person who was born in a particular place
#
#
# 228
# words: ['native']
# def: a person born in a particular place or country
#
#
# 229
# words: ['neglecter']
# def: a person who is neglectful and gives little attention or respect to people or responsibilities
#
#
# 230
# words: ['neighbor', 'neighbour']
# def: a person who lives (or is located) near another
#
#
# 231
# words: ['neutral']
# def: one who does not side with any party in a war or dispute
#
#
# 232
# words: ['nondescript']
# def: a person is not easily classified and not very interesting
#
#
# 233
# words: ['nonmember']
# def: a person who is not a member
#
#
# 234
# words: ['nonparticipant']
# def: a person who does not participate
#
#
# 235
# words: ['nonpartisan', 'nonpartizan']
# def: a person who is nonpartisan
#
#
# 236
# words: ['nonperson', 'unperson']
# def: a person regarded as nonexistent and having no rights; a person whose existence is systematically ignored (especially for ideological or political reasons)
#
#
# 237
# words: ['nonreligious_person']
# def: a person who does not manifest devotion to a deity
#
#
# 238
# words: ['nonresident']
# def: someone who does not live in a particular place
#
#
# 239
# words: ['nonsmoker']
# def: a person who does not smoke tobacco
#
#
# 240
# words: ['nonworker']
# def: a person who does nothing
#
#
# 241
# words: ['nude', 'nude_person']
# def: a naked person
#
#
# 242
# words: ['nurser']
# def: a person who treats something carefully
#
#
# 243
# words: ['occultist']
# def: a believer in occultism; someone versed in the occult arts
#
#
# 244
# words: ['optimist']
# def: a person disposed to take a favorable view of things
#
#
# 245
# words: ['orphan']
# def: someone or something who lacks support or care or supervision
#
#
# 246
# words: ['ostrich']
# def: a person who refuses to face reality or recognize the truth (a reference to the popular notion that the ostrich hides from danger by burying its head in the sand)
#
#
# 247
# words: ['ouster', 'ejector']
# def: a person who ousts or supplants someone else
#
#
# 248
# words: ['outcaste']
# def: a person belonging to no caste
#
#
# 249
# words: ['outdoorsman']
# def: a person who spends time outdoors (e.g., hunting or fishing)
#
#
# 250
# words: ['owner', 'possessor']
# def: a person who owns something
#
#
# 251
# words: ['pamperer', 'spoiler', 'coddler', 'mollycoddler']
# def: someone who pampers or spoils by excessive indulgence
#
#
# 252
# words: ['pansexual']
# def: a person who participates in (or is open to) sexual activities of many kinds
#
#
# 253
# words: ['pardoner', 'forgiver', 'excuser']
# def: a person who pardons or forgives or excuses a fault or offense
#
#
# 254
# words: ['partner']
# def: a person who is a member of a partnership
#
#
# 255
# words: ['party']
# def: a person involved in legal proceedings
#
#
# 256
# words: ['passer']
# def: a person who passes as a member of a different ethnic or racial group
#
#
# 257
# words: ['peer', 'equal', 'match', 'compeer']
# def: a person who is of equal standing with another in a group
#
#
# 258
# words: ['perceiver', 'percipient', 'observer', 'beholder']
# def: a person who becomes aware (of things or events) through the senses
#
#
# 259
# words: ['percher']
# def: a person situated on a perch
#
#
# 260
# words: ['person_of_color', 'person_of_colour']
# def: (formal) any non-European non-white person
#
#
# 261
# words: ['personage']
# def: another word for person; a person not meriting identification
#
#
# 262
# words: ['personification']
# def: a person who represents an abstract quality
#
#
# 263
# words: ['perspirer', 'sweater']
# def: a person who perspires
#
#
# 264
# words: ['philosopher']
# def: a wise person who is calm and rational; someone who lives a life of reason with equanimity
#
#
# 265
# words: ['picker', 'chooser', 'selector']
# def: a person who chooses or selects out
#
#
# 266
# words: ['Pisces', 'Fish']
# def: (astrology) a person who is born while the sun is in Pisces
#
#
# 267
# words: ['pisser', 'urinator']
# def: a person who urinates
#
#
# 268
# words: ['planner', 'contriver', 'deviser']
# def: a person who makes plans
#
#
# 269
# words: ['player']
# def: a person who pursues a number of different social and sexual partners simultaneously
#
#
# 270
# words: ['posturer']
# def: someone who behaves in a manner calculated to impress or mislead others
#
#
# 271
# words: ['powderer']
# def: someone who applies or scatters powder
#
#
# 272
# words: ['precursor', 'forerunner']
# def: a person who goes before or announces the coming of another
#
#
# 273
# words: ['preserver']
# def: someone who keeps safe from harm or danger
#
#
# 274
# words: ['primitive', 'primitive_person']
# def: a person who belongs to an early stage of civilization
#
#
# 275
# words: ['propositus']
# def: the person immediately affected by or concerned with an action
#
#
# 276
# words: ['public_relations_person']
# def: a person employed to establish and promote a favorable relationship with the public
#
#
# 277
# words: ['pursuer']
# def: a person who pursues some plan or goal
#
#
# 278
# words: ['pussycat']
# def: a person who is regarded as easygoing and agreeable
#
#
# 279
# words: ['quarter']
# def: an unspecified person
#
#
# 280
# words: ['quitter']
# def: a person who gives up too easily
#
#
# 281
# words: ['radical']
# def: a person who has radical ideas or opinions
#
#
# 282
# words: ['realist']
# def: a person who accepts the world as it literally is and deals with it accordingly
#
#
# 283
# words: ['rectifier']
# def: a person who corrects or sets right
#
#
# 284
# words: ['redhead', 'redheader', 'red-header', 'carrottop']
# def: someone who has red hair
#
#
# 285
# words: ['registrant']
# def: a person who is formally entered (along with others) in a register (and who obtains certain rights thereby)
#
#
# 286
# words: ['relative', 'relation']
# def: a person related by blood or marriage
#
#
# 287
# words: ['reliever', 'allayer', 'comforter']
# def: a person who reduces the intensity (e.g., of fears) and calms and pacifies
#
#
# 288
# words: ['religious_person']
# def: a person who manifests devotion to a deity
#
#
# 289
# words: ['repeater']
# def: a person who repeats
#
#
# 290
# words: ['rescuer', 'recoverer', 'saver']
# def: someone who saves something from danger or violence
#
#
# 291
# words: ['rester']
# def: a person who rests
#
#
# 292
# words: ['restrainer', 'controller']
# def: a person who directs and restrains
#
#
# 293
# words: ['revenant']
# def: a person who returns after a lengthy absence
#
#
# 294
# words: ['rich_person', 'wealthy_person', 'have']
# def: a person who possesses great material wealth
#
#
# 295
# words: ['right-hander', 'right_hander', 'righthander']
# def: a person who uses the right hand more skillfully than the left
#
#
# 296
# words: ['riser']
# def: a person who rises (especially from bed)
#
#
# 297
# words: ['romper']
# def: a person who romps or frolics
#
#
# 298
# words: ['roundhead']
# def: a brachycephalic person
#
#
# 299
# words: ['ruler', 'swayer']
# def: a person who rules or commands
#
#
# 300
# words: ['rusher']
# def: a person who rushes; someone in a hurry; someone who acts precipitously
#
#
# 301
# words: ['Sagittarius', 'Archer']
# def: (astrology) a person who is born while the sun is in Sagittarius
#
#
# 302
# words: ['scientist']
# def: a person with advanced knowledge of one or more sciences
#
#
# 303
# words: ['Scorpio', 'Scorpion']
# def: (astrology) a person who is born while the sun is in Scorpio
#
#
# 304
# words: ['scratcher']
# def: a person who scratches to relieve an itch
#
#
# 305
# words: ['second-rater', 'mediocrity']
# def: a person of second-rate ability or value
#
#
# 306
# words: ['seeder', 'cloud_seeder']
# def: a person who seeds clouds
#
#
# 307
# words: ['seeker', 'searcher', 'quester']
# def: someone making a search or inquiry
#
#
# 308
# words: ['segregate']
# def: someone who is or has been segregated
#
#
# 309
# words: ['self']
# def: a person considered as a unique individual
#
#
# 310
# words: ['sensualist']
# def: a person who enjoys sensuality
#
#
# 311
# words: ['sentimentalist', 'romanticist']
# def: someone who indulges in excessive sentimentality
#
#
# 312
# words: ['sex_object']
# def: any person regarded simply as an object of sexual gratification
#
#
# 313
# words: ['sex_symbol']
# def: a person (especially a celebrity) who is well-known for their sexual attractiveness
#
#
# 314
# words: ['shaker', 'mover_and_shaker']
# def: a person who wields power and influence
#
#
# 315
# words: ['showman']
# def: a person skilled at making effective presentations
#
#
# 316
# words: ['signer', 'signatory']
# def: someone who signs and is bound by a document
#
#
# 317
# words: ['simpleton', 'simple']
# def: a person lacking intelligence or common sense
#
#
# 318
# words: ['six-footer']
# def: a person who is at least six feet tall
#
#
# 319
# words: ['skidder', 'slider', 'slipper']
# def: a person who slips or slides because of loss of traction
#
#
# 320
# words: ['Slav']
# def: any member of the people of eastern Europe or Asian Russia who speak a Slavonic language
#
#
# 321
# words: ['slave']
# def: a person who is owned by someone
#
#
# 322
# words: ['slave']
# def: someone entirely dominated by some influence or person
#
#
# 323
# words: ['sleepyhead']
# def: a sleepy person
#
#
# 324
# words: ['sloucher']
# def: a person who slouches; someone with a drooping carriage
#
#
# 325
# words: ['small_person']
# def: a person of below average size
#
#
# 326
# words: ['smasher']
# def: a person who smashes something
#
#
# 327
# words: ['smiler']
# def: a person who smiles
#
#
# 328
# words: ['sneezer']
# def: a person who sneezes
#
#
# 329
# words: ['sniffer']
# def: a person who sniffs
#
#
# 330
# words: ['sniffler', 'sniveler']
# def: a person who breathes audibly through a congested nose
#
#
# 331
# words: ['snuffer']
# def: a person who snuffs out candles
#
#
# 332
# words: ['snuffler']
# def: a person who breathes noisily (as through a nose blocked by mucus)
#
#
# 333
# words: ['socializer', 'socialiser']
# def: a person who takes part in social activities
#
#
# 334
# words: ['sort']
# def: a person of a particular character or nature
#
#
# 335
# words: ['sounding_board']
# def: a person whose reactions to something serve as an indication of its acceptability
#
#
# 336
# words: ['sphinx']
# def: an inscrutable person who keeps his thoughts and intentions secret
#
#
# 337
# words: ['spitter', 'expectorator']
# def: a person who spits (ejects saliva or phlegm from the mouth)
#
#
# 338
# words: ['sport']
# def: a person known for the way she (or he) behaves when teased or defeated or subjected to trying circumstances
#
#
# 339
# words: ['sprawler']
# def: a person who sprawls
#
#
# 340
# words: ['spurner']
# def: a person who rejects (someone or something) with contempt
#
#
# 341
# words: ['squinter', 'squint-eye']
# def: a person with strabismus
#
#
# 342
# words: ['stifler', 'smotherer']
# def: a person who stifles or smothers or suppresses
#
#
# 343
# words: ['stigmatic', 'stigmatist']
# def: a person whose body is marked by religious stigmata (such as marks resembling the wounds of the crucified Christ)
#
#
# 344
# words: ['stooper']
# def: a person who carries himself or herself with the head and shoulders habitually bent forward
#
#
# 345
# words: ['stranger']
# def: an individual that one is not acquainted with
#
#
# 346
# words: ['struggler']
# def: a person who struggles with difficulties or with great effort
#
#
# 347
# words: ['subject', 'case', 'guinea_pig']
# def: a person who is subjected to experimental or other observational procedures; someone who is an object of investigation
#
#
# 348
# words: ['supernumerary']
# def: a person serving no apparent function
#
#
# 349
# words: ['surrenderer', 'yielder']
# def: a person who yields or surrenders
#
#
# 350
# words: ['survivalist']
# def: someone who tries to insure their personal survival or the survival of their group or nation
#
#
# 351
# words: ['survivor']
# def: one who outlives another
#
#
# 352
# words: ['suspect']
# def: someone who is under suspicion
#
#
# 353
# words: ['tagger']
# def: someone who assigns labels to the grammatical constituents of textual matter
#
#
# 354
# words: ['tagger']
# def: someone who appends or joins one thing to another
#
#
# 355
# words: ['tapper']
# def: a person who strikes a surface lightly and usually repeatedly
#
#
# 356
# words: ['Taurus', 'Bull']
# def: (astrology) a person who is born while the sun is in Taurus
#
#
# 357
# words: ['tempter']
# def: a person who tempts others
#
#
# 358
# words: ['termer']
# def: a person who serves a specified term
#
#
# 359
# words: ['terror', 'scourge', 'threat']
# def: a person who inspires fear or dread
#
#
# 360
# words: ['testator', 'testate']
# def: a person who makes a will
#
#
# 361
# words: ['thin_person', 'skin_and_bones', 'scrag']
# def: a person who is unusually thin and scrawny
#
#
# 362
# words: ['third-rater']
# def: one who is third-rate or distinctly inferior
#
#
# 363
# words: ['thrower']
# def: someone who projects something (especially by a rapid motion of the arm)
#
#
# 364
# words: ['tiger']
# def: a fierce or audacious person
#
#
# 365
# words: ['totemist']
# def: a person who belongs to a clan or tribe having a totem
#
#
# 366
# words: ['toucher']
# def: a person who causes or allows a part of the body to come in contact with someone or something
#
#
# 367
# words: ['transfer', 'transferee']
# def: someone who transfers or is transferred from one position to another
#
#
# 368
# words: ['transsexual', 'transexual']
# def: a person whose sexual identification is entirely with the opposite sex
#
#
# 369
# words: ['transvestite', 'cross-dresser']
# def: someone who adopts the dress or manner or sexual role of the opposite sex
#
#
# 370
# words: ['traveler', 'traveller']
# def: a person who changes location
#
#
# 371
# words: ['trier', 'attempter', 'essayer']
# def: one who tries
#
#
# 372
# words: ['turner']
# def: one of two persons who swing ropes for jumpers to skip over in the game of jump rope
#
#
# 373
# words: ['tyrant']
# def: any person who exercises power in a cruel way
#
#
# 374
# words: ['undoer', 'opener', 'unfastener', 'untier']
# def: a person who unfastens or unwraps or opens
#
#
# 375
# words: ['unfortunate', 'unfortunate_person']
# def: a person who suffers misfortune
#
#
# 376
# words: ['unskilled_person']
# def: a person who lacks technical training
#
#
# 377
# words: ['unwelcome_person', 'persona_non_grata']
# def: a person who for some reason is not wanted or welcome
#
#
# 378
# words: ['user']
# def: a person who makes use of a thing; someone who uses or employs something
#
#
# 379
# words: ['vanisher']
# def: a person who disappears
#
#
# 380
# words: ['victim', 'dupe']
# def: a person who is tricked or swindled
#
#
# 381
# words: ['Victorian']
# def: a person who lived during the reign of Victoria
#
#
# 382
# words: ['Virgo', 'Virgin']
# def: (astrology) a person who is born while the sun is in Virgo
#
#
# 383
# words: ['visionary']
# def: a person given to fanciful speculations and enthusiasms with little regard for what is actually possible
#
#
# 384
# words: ['visually_impaired_person']
# def: someone who has inferior vision
#
#
# 385
# words: ['waiter']
# def: a person who waits or awaits
#
#
# 386
# words: ['waker']
# def: a person who awakes
#
#
# 387
# words: ['walk-in']
# def: person who walks in without having an appointment
#
#
# 388
# words: ['wanter', 'needer']
# def: a person who wants or needs something
#
#
# 389
# words: ['ward']
# def: a person who is under the protection or in the custody of another
#
#
# 390
# words: ['warrior']
# def: someone engaged in or experienced in warfare
#
#
# 391
# words: ['watcher']
# def: a person who keeps a devotional vigil by a sick bed or by a dead body
#
#
# 392
# words: ['weakling', 'doormat', 'wuss']
# def: a person who is physically weak and ineffectual
#
#
# 393
# words: ['weasel']
# def: a person who is regarded as treacherous or sneaky
#
#
# 394
# words: ['White', 'White_person', 'Caucasian']
# def: a member of the Caucasoid race
#
#
# 395
# words: ['wiggler', 'wriggler', 'squirmer']
# def: one who can't stay still (especially a child)
#
#
# 396
# words: ['winker']
# def: a person who winks
#
#
# 397
# words: ['withholder']
# def: a person who refrains from granting
#
#
# 398
# words: ['witness']
# def: (law) a person who testifies under oath in a court of law
#
#
# 399
# words: ['worker']
# def: a person who works at a specific occupation
#
#
# 400
# words: ['worldling']
# def: a person absorbed by the concerns and interests and pleasures of the present world
#
#
# 401
# words: ['yawner']
# def: a person who yawns

# %%
white_colar
blue_colar
butcher
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1568d00a9a96> in <module>
# ----> 1 white_colar
#       2 blue_colar
#       3 butcher
#
# NameError: name 'white_colar' is not defined
